# %%
import wikipedia

# %%
wikipedia.summary("Indonesia", sentences=4)
# Out:
# "Indonesia, officially the Republic of Indonesia, is a country in Southeast Asia and Oceania between the Indian and Pacific oceans. It consists of over 17,000 islands, including Sumatra, Java, Sulawesi, and parts of Borneo and New Guinea. Indonesia is the world's largest archipelagic state and the 14th-largest country by area, at 1,904,569 square kilometres (735,358 square miles). With over 277 million people, Indonesia is the world's fourth-most populous country and the most populous Muslim-majority country."

# %%
wikipedia.search("Indonesia")
# Out:
# ['Indonesia',
#  'Indonesian language',
#  'Indonesians',
#  'Indonesian',
#  'COVID-19 pandemic in Indonesia',
#  'Sikhism in Indonesia',
#  'Indonesian National Revolution',
#  'Indonesia national under-17 football team',
#  'List of Indonesian cities by population',
#  'Music of Indonesia']

# %%
page = wikipedia.page("Indonesia")

# %%
page.title
# Out:
# 'Indonesia'

# %%
page.categories
# Out:
# ['1945 establishments in Asia',
#  '1945 establishments in Indonesia',
#  '1945 establishments in Southeast Asia',
#  'All articles containing potentially dated statements',
#  'All articles with unsourced statements',
#  'Articles containing Ancient Greek (to 1453)-language text',
#  'Articles containing Dutch-language text',
#  'Articles containing Filipino-language text',
#  'Articles containing German-language text',
#  'Articles containing Indonesian-language text',
#  'Articles containing Kawi-language text',
#  'Articles containing potentially dated statements from 2018',
#  'Articles containing potentially dated statements from 2019',
#  'Articles with BNF identifiers',
#  'Articles with Curlie links',
#  'Articles with EMU identifiers',
#  'Articles with FAST identifiers',
#  'Articles with GND identifiers',
#  'Articles with HDS identifiers',
#  'Articles with ISNI identifiers',
#  'Articles with Indonesian-language sources (id)',
#  'Articles with J9U identifiers',
#  'Articles with LCCN identifiers',
#  'Articles with MusicBrainz area identifiers',
#  'Articles with NARA identifiers',
#  'Articles with NDL identifiers',
#  'Articles with NKC identifiers',
#  'Articles with SUDOC identifiers',
#  'Articles with TDVİA identifiers',
#  'Articles with VIAF identifiers',
#  'Articles with WORLDCATID identifiers',
#  'Articles with hAudio microformats',
#  'Articles with short description',
#  'Articles with unsourced statements from August 2020',
#  'Articles with unsourced statements from December 2020',
#  'CS1 French-language sources (fr)',
#  'CS1 Indonesian-language sources (id)',
#  'Coordinates on Wikidata',
#  'Countries in Asia',
#  'Countries in Melanesia',
#  'Developing 8 Countries member states',
#  'E7 nations',
#  'Former OPEC member states',
#  'G15 nations',
#  'G20 nations',
#  'Harv and Sfn no-target errors',
#  'Indonesia',
#  'Island countries',
#  'Malay-speaking countries and territories',
#  'Member states of ASEAN',
#  'Member states of the Organisation of Islamic Cooperation',
#  'Member states of the United Nations',
#  'Newly industrializing countries',
#  'Pages including recorded pronunciations',
#  'Pages using Sister project links with default search',
#  'Pages using Sister project links with hidden wikidata',
#  'Pages using infobox country or infobox former country with the symbol caption or type parameters',
#  'Pages using largest cities with class',
#  'Pages using multiple image with auto scaled images',
#  'Republics',
#  'Short description matches Wikidata',
#  'Source attribution',
#  'Southeast Asian countries',
#  'States and territories established in 1945',
#  'Transcontinental countries',
#  'Use British English from September 2019',
#  'Use dmy dates from June 2019',
#  'Webarchive template wayback links',
#  'Wikipedia articles needing page number citations from December 2016',
#  'Wikipedia articles needing page number citations from October 2020',
#  'Wikipedia indefinitely move-protected pages',
#  'Wikipedia pages semi-protected against vandalism']

# %%
page.content
# Out:
# 'Indonesia, officially the Republic of Indonesia, is a country in Southeast Asia and Oceania between the Indian and Pacific oceans. It consists of over 17,000 islands, including Sumatra, Java, Sulawesi, and parts of Borneo and New Guinea. Indonesia is the world\'s largest archipelagic state and the 14th-largest country by area, at 1,904,569 square kilometres (735,358 square miles). With over 277 million people, Indonesia is the world\'s fourth-most populous country and the most populous Muslim-majority country. Java, the world\'s most populous island, is home to more than half of the country\'s population.\nIndonesia is a presidential republic with an elected legislature. It has 37 provinces, of which eight have special status. The country\'s capital, Jakarta, is the world\'s second-most populous urban area. Indonesia shares land borders with Papua New Guinea, East Timor, and the eastern part of Malaysia, as well as maritime borders with Singapore, Vietnam, Thailand, the Philippines, Australia, Palau, and India (Andaman and Nicobar Islands). Despite its large population and densely populated regions, Indonesia has vast areas of wilderness that support one of the world\'s highest levels of biodiversity.\nThe Indonesian archipelago has been a valuable region for trade since at least the 7th century when Srivijaya and later Majapahit traded with entities from mainland China and the Indian subcontinent. Local rulers gradually absorbed foreign influences from the early centuries, and Hindu and Buddhist kingdoms flourished. Sunni traders and Sufi scholars brought Islam, while Christianity was spread by European missionaries. Although the Portuguese, the French and British also ruled at some point, the Dutch were the foremost colonial power for much of their 350-year presence in the archipelago. The concept of "Indonesia" as a nation-state emerged in the early 20th century, culminating later in the proclamation of Indonesian Independence in 1945. However, it was not until 1949 that the Dutch recognised Indonesia\'s sovereignty following an armed and diplomatic conflict between the two.\nIndonesia consists of thousands of distinct native ethnic and hundreds of linguistic groups, with Javanese being the largest. A shared identity has developed with the motto "Bhinneka Tunggal Ika" ("Unity in Diversity" literally, "many, yet one"), defined by a national language, cultural diversity, religious pluralism within a Muslim-majority population, and a history of colonialism and rebellion against it. The economy of Indonesia is the world\'s 17th-largest by nominal GDP and the 7th-largest by PPP. It is a regional power and is considered a middle power in global affairs. The country is a member of several multilateral organisations, including the United Nations, World Trade Organization, G20, and a founding member of the Non-Aligned Movement, Association of Southeast Asian Nations, East Asia Summit, D-8 and the Organisation of Islamic Cooperation.\n\n\n== Etymology ==\n\nThe name Indonesia derives from the Greek words Indos (Ἰνδός) and nesos (νῆσος), meaning "Indian islands". The name dates back to the 19th century, far predating the formation of independent Indonesia. In 1850, George Windsor Earl, an English ethnologist, proposed the terms Indunesians—and, his preference, Malayunesians—for the inhabitants of the "Indian Archipelago or Malay Archipelago". In the same publication, one of his students, James Richardson Logan, used Indonesia as a synonym for Indian Archipelago. Dutch academics writing in East Indies publications were reluctant to use Indonesia. They preferred Malay Archipelago (Dutch: Maleische Archipel); the Netherlands East Indies (Nederlandsch Oost Indië), popularly Indië; the East (de Oost); and Insulinde.After 1900, Indonesia became more common in academic circles outside the Netherlands, and native nationalist groups adopted it for political expression. Adolf Bastian of the University of Berlin popularized the name through his ...

# %%
page.links
# Out:
# ['+62',
#  '.id',
#  '1000000000000000 (number)',
#  '10th Summit of the Non-Aligned Movement',
#  '11th parallel south',
#  '141st meridian east',
#  '16th Summit of the Non-Aligned Movement',
#  '1815 eruption of Mount Tambora',
#  '1883 eruption of Krakatoa',
#  '18th Summit of the Non-Aligned Movement',
#  '1938 FIFA World Cup',
#  '1958 Asian Games',
#  '1987 Southeast Asian Games',
#  '1990 oil price shock',
#  '1991 Southeast Asian Games',
#  '1996 AFC Asian Cup',
#  '1997 Asian financial crisis',
#  '19th century',
#  '1st Summit of the Non-Aligned Movement',
#  '2004 Indian Ocean earthquake and tsunami',
#  '2004 Indonesian presidential election',
#  '2006 Yogyakarta earthquake',
#  '2010 AFF Championship',
#  '2011 Southeast Asian Games',
#  '2015 Indonesian local elections',
#  '2017 ASEAN Summits',
#  '2019 Indonesian general election',
#  '2020 Indonesian census',
#  '2nd Summit of the Non-Aligned Movement',
#  '30 September Movement',
#  '3rd Summit of the Non-Aligned Movement',
#  '45th Pacific Islands Forum',
#  '4th Summit of the Non-Aligned Movement',
#  '51st Pacific Islands Forum',
#  '5th Summit of the Non-Aligned Movement',
#  '6th Summit of the Non-Aligned Movement',
#  '6th parallel north',
#  '7th Summit of the Non-Aligned Movement',
#  '8th Summit of the Non-Aligned Movement',
#  '95th meridian east',
#  '9th Summit of the Non-Aligned Movement',
#  'AFC Asian Cup',
#  'AFF Championship',
#  'APEC Australia 1989',
#  'APEC Australia 2007',
#  'APEC Brunei 2000',
#  'APEC Business Travel Card',
#  'APEC Canada 1997',
#  'APEC Chile 2004',
#  'APEC Chile 2019',
#  'APEC China 2001',
#  'APEC China 2014',
#  'APEC Climate Center',
#  'APEC Indonesia 1994',
#  'APEC Indonesia 2013',
#  'APEC Japan 1995',
#  'APEC Japan 2010',
#  'APEC Malaysia 1998',
#  'APEC Malaysia 2020',
#  'APEC Mexico 2002',
#  'APEC New Zealand 1999',
#  'APEC New Zealand 2021',
#  'APEC Papua New Guinea 2018',
#  'APEC Peru 2008',
#  'APEC Peru 2016',
#  'APEC Philippines 1996',
#  'APEC Philippines 2015',
#  'APEC Republic of Korea 1991',
#  'APEC Russia 2012',
#  'APEC Sculpture Garden',
#  'APEC Singapore 1990',
#  'APEC Singapore 2009',
#  'APEC South Korea 2005',
#  'APEC Thailand 1992',
#  'APEC Thailand 2003',
#  'APEC Thailand 2022',
#  'APEC United States 1993',
#  'APEC United States 2011',
#  'APEC Vietnam 2006',
#  'APEC Vietnam 2017',
#  'APEC Youth Science Festival',
#  'APEC blue',
#  'ASEAN',
#  'ASEAN Armies Rifle Meet',
#  'ASEAN Centre for Biodiversity',
#  'ASEAN Charter',
#  'ASEAN Commission on the Promotion and Protection of the Rights of Women',
#  'ASEAN Common Time',
#  'ASEAN Declaration',
#  'ASEAN Football Federation',
#  'ASEAN Free Trade Area',
#  'ASEAN Human Rights Declaration',
#  'ASEAN Intergovernmental Commission on Human Rights',
#  'ASEAN Outstanding Scientist and Technologist Award',
#  'ASEAN Para Games',
#  'ASEAN Regional Forum',
#  'ASEAN Rise',
#  'ASEAN School Games',
#  'ASEAN Smart Cities Network',
#  'ASEAN Song of Unity',
#  'ASEAN Summit',
#  'ASEAN University Games',
#  'ASEAN–Australia Development Cooperation Program',
#  'ASEAN–China Free Trade Area',
#  'ASEAN–European Union relations',
#  'ASEAN–India Commemorative Summit',
#  'ASEAN–India Free Trade Area',
#  'ASEAN–Republic of Korea Commemorative Summit',
#  'Abangan',
#  'Abkhazia',
#  'Accession of East Timor to ASEAN',
#  'Accession of Papua New Guinea to ASEAN',
#  'Aceh',
#  'Aceh War',
#  'Ada Apa dengan Cinta?',
#  'Administrative divisions of Indonesia',
#  'Adolf Bastian',
#  'Afghanistan',
#  'African, Caribbean and Pacific Group of States',
#  'African Union',
#  'Agriculture in Indonesia',
#  'Ahmadiyya in Indonesia',
#  'Air quality',
#  'Airbus',
#  'Akrotiri and Dhekelia',
#  'Albania',
#  'Alfred Russel Wallace',
#  'Algeria',
#  'Aliran Kepercayaan',
#  'American English',
#  'American Samoa',
#  'Ancient Greek',
#  'Andaman and Nicobar Islands',
#  'Angklung',
#  'Animism',
#  'Anoa (armoured personnel carrier)',
#  'Aquaculture',
#  'Arab League',
#  'Arab world',
#  'Archipelagic state',
#  'Architecture of India',
#  'Architecture of Indonesia',
#  'Argentina',
#  'Ariel Heryanto',
#  'Armenia',
#  'Armorial of Indonesia',
#  'Ashmore and Cartier Islands',
#  'Asia',
#  'Asia-Pacific Economic Cooperation',
#  'Asian Development Bank',
#  'Asian Monetary Unit',
#  'Asian Survey',
#  'Asian elephant',
#  'Asia–Europe Meeting',
#  'Asmat people',
#  'Association football',
#  'Australasian realm',
#  'Australia',
#  'Austronesian languages',
#  'Austronesian peoples',
#  'Automotive industry in Indonesia',
#  'Autonomous administrative division',
#  'Aviation in Indonesia',
#  'Ayu Utami',
#  'Azerbaijan',
#  'B. J. Habibie',
#  'BBC News',
#  'Babad Tanah Jawi',
#  'Babinsa',
#  'Badan Informasi Geospasial',
#  'Badan Pengawas Tenaga Nuklir',
#  'Badan Standardisasi Nasional',
#  'Badminton',
#  'Bahrain',
#  'Baiturrahman Grand Mosque',
#  'Baker Island',
#  'Balai Pustaka',
#  'Bali',
#  'Bali myna',
#  'Balinese Hinduism',
#  'Balinese architecture',
#  'Balinese art',
#  'Balinese dance',
#  'Balinese people',
#  'Balinese temple',
#  'Banda Aceh',
#  'Banda Islands',
#  'Bandar Lampung',
#  'Bandung',
#  'Bandung Conference',
#  'Bandung Institute of Technology',
#  'Bangka Belitung Islands',
#  'Bangladesh',
#  'Bank Indonesia',
#  'Banten',
#  'Barito River',
#  'Basketball',
#  'Batak',
#  'Batak people',
#  'Batam',
#  'Batavian Republic',
#  'Batik',
#  'Bekasi',
#  'Bengkulu',
#  'Benin',
#  'Besakih Temple',
#  'Betawi people',
#  'Bhinneka Tunggal Ika',
#  'Bhutan',
#  'Bibcode (identifier)',
#  'Bibliography of Indonesia',
#  'Biosphere reserves of Indonesia',
#  'Boeing',
#  'Bogor',
#  'Bogor Regency',
#  'Bonin Islands',
#  'Borneo',
#  'Borobudur',
#  'Borobudur ship',
#  'Bosnia and Herzegovina',
#  'Boxing',
#  'Brazil',
#  'British Empire',
#  'British English',
#  'British Indian Ocean Territory',
#  'British Overseas Territories',
#  'British thermal unit',
#  'Brunei',
#  'Buddhism',
#  'Buddhism in Indonesia',
#  'Bugis',
#  'Bugis people',
#  'Bunaken National Park',
#  'Burkina Faso',
#  'CASA/IPTN CN-235',
#  'COVID-19 pandemic',
#  'Cabinet Secretariat (Indonesia)',
#  'Cabinet of Indonesia',
#  'Cairns Group',
#  'Calvinism',
#  'Cambodia',
#  'Cambridge University Press',
#  'Cameroon',
#  'Canada',
#  'Candi of Indonesia',
#  'Capital city of Indonesia',
#  'Capital of Indonesia',
#  'Catatan Si Boy',
#  'Catholic Church',
#  'Catholic Church in Indonesia',
#  'Central African Republic',
#  'Central Intelligence Agency',
#  'Central Java',
#  'Central Kalimantan',
#  'Central Papua',
#  'Central Sulawesi',
#  'Central Sumatra',
#  'Chad',
#  'Chairil Anwar',
#  'Chiang Mai Initiative',
#  'Chief Justice of the Supreme Court of Indonesia',
#  'Child labor',
#  'Chile',
#  'China',
#  'Chinese Indonesians',
#  'Christianity in Indonesia',
#  'Christians',
#  'Christmas Island',
#  'Cinema of Indonesia',
#  'Citra Award',
#  'City status in Indonesia',
#  'Climate change in Indonesia',
#  'Climate of Indonesia',
#  'Cloves',
#  'Coat of arms of Indonesia',
#  'Cockfighting',
#  'Coconut milk',
#  'Cocos (Keeling) Islands',
#  'Colonial architecture of Indonesia',
#  'Commander-in-chief',
#  'Commonwealth of Nations',
#  'Communications in Indonesia',
#  'Communist Party of Indonesia',
#  'Comoros',
#  'Comparison of Indonesian and Standard Malay',
#  'Comprehensive Economic Partnership for East Asia',
#  'Confucianism in Indonesia',
#  'Conservation International',
#  'Constitution of Indonesia',
#  'Constitutional Assembly of Indonesia',
#  'Constitutional Court of Indonesia',
#  'Contemporary art',
#  'Cook Islands',
#  'Coordinated Universal Time',
#  'Coordinating Ministry for Economic Affairs (Indonesia)',
#  'Coordinating Ministry for Human Development and Cultural Affairs',
#  'Coordinating Ministry for Maritime Affairs (Indonesia)',
#  'Coordinating Ministry for Maritime and Investments Affairs (Indonesia)',
#  'Coordinating Ministry for Political, Legal, and Security Affairs (Indonesia)',
#  'Coral Sea Islands',
#  'Coral Triangle',
#  'Coral reef fish',
#  'Cornell University Press',
#  'Corruption Eradication Commission',
#  'Country code top-level domain',
#  'Crime in Indonesia',
#  'Cuba',
#  'Cultural properties of Indonesia',
#  'Culture of Indonesia',
#  'Curlie',
#  'Cyprus',
#  'Cyprus and the Non-Aligned Movement',
#  'D-8 Organization for Economic Cooperation',
#  'DPR/MPR Building',
#  'Dance in Indonesia',
#  'Dangdut',
#  'Dayak people',
#  'Deforestation',
#  'Deforestation in Indonesia',
#  'Democratic Party (Indonesia)',
#  'Demographia',
#  'Demographics of Indonesia',
#  'Demonym',
#  'Dendeng',
#  'Denpasar',
#  'Dependent territory',
#  'Depok',
#  'Dharma',
#  'Diponegoro',
#  'Discrimination against Chinese Indonesians',
#  'Districts of Indonesia',
#  'Djibouti',
#  'Doi (identifier)',
#  'Dry season',
#  'Dutch-based creole languages',
#  'Dutch East India Company',
#  'Dutch East India Company in Indonesia',
#  'Dutch East Indies',
#  'Dutch East Indies campaign',
#  'Dutch Empire',
#  'Dutch New Guinea',
#  'Dutch architecture in Semarang',
#  'Dutch language',
#  'Dutch people',
#  'Dutch–Indonesian Round Table Conference',
#  'Dwifungsi',
#  'Dynamism (metaphysics)',
#  'EADS CASA',
#  'East Asia Summit',
#  'East Java',
#  'East Kalimantan',
#  'East Malaysia',
#  'East Nusa Tenggara',
#  'East Timor',
#  'East Timor (province)',
#  'East Timor genocide',
#  'East Timor–Indonesia border',
#  'Easter Island',
#  'Economic Cooperation Organization',
#  'Economic history of Indonesia',
#  'Economy of Indonesia',
#  'Ecuador',
#  'Education in Indonesia',
#  'Egypt',
#  'Egypt and the Non-Aligned Movement',
#  "Eighty Years' War",
#  'Election threshold',
#  'Elections in Indonesia',
#  'Embassy of Indonesia, Canberra',
#  'Emblem of the Association of Southeast Asian Nations',
#  'Empire of Japan',
#  'Encyclopædia Britannica',
#  'Energy in Indonesia',
#  'Enlargement of ASEAN',
#  'Environmental Performance Index',
#  'Environmental issues in Indonesia',
#  'Eric Franklin Wood',
#  'Ethnic group',
#  'Ethnic groups in Indonesia',
#  'Ethnology',
#  'Eurasian (mixed ancestry)',
#  'Eurasian plate',
#  'Europe',
#  'European Union',
#  'FIFA World Cup',
#  'Fall of Suharto',
#  'Fauna of Indonesia',
#  'Fauna of New Guinea',
#  'Federated States of Micronesia',
#  'Fidel Castro',
#  'Fiji',
#  'Financial Services Authority (Indonesia)',
#  'Financial Times',
#  'First inauguration of Joko Widodo',
#  'Five Principles of Peaceful Coexistence',
#  'Flag of Indonesia',
#  'Flag of the Association of Southeast Asian Nations',
#  'Flora of Indonesia',
#  'Flores',
#  'Folklore of Indonesia',
#  'Foot (unit)',
#  'Forced labour',
#  'Foreign direct investment',
#  'Foreign relations of Indonesia',
#  'France',
#  'Francis Xavier',
#  'Francisco Serrão',
#  'French Polynesia',
#  'French and British interregnum in the Dutch East Indies',
#  'G20',
#  'Gabon',
#  'Gadjah Mada University',
#  'Gado-gado',
#  'Gajah Mada',
#  'Galápagos Islands',
#  'Gamal Abdel Nasser',
#  'Gamelan',
#  'Garuda',
#  'Garuda Indonesia',
#  'Gelora Bung Karno Stadium',
#  'General Elections Commission (Indonesia)',
#  'Genetic bottleneck',
#  'Geographic coordinate system',
#  'Geography of Indonesia',
#  'Geology of Indonesia',
#  'George Windsor Earl',
#  'Georgia (country)',
#  'Germany',
#  'Ghana',
#  'Gini coefficient',
#  'Global Innovation Index',
#  'Golkar',
#  'Gong',
#  'Google Books',
#  'Gorontalo',
#  'Governance of Indonesia',
#  'Government of Indonesia',
#  'Great Indonesia Movement Party',
#  'Great Recession',
#  'Greater India',
#  'Greater bird-of-paradise',
#  'Gross domestic product',
#  'Guam',
#  'Guided Democracy in Indonesia',
#  'Guinea',
#  'Guinea-Bissau',
#  'Gulai',
#  'Gurindam',
#  'Guyana',
#  'Harvard University Press',
#  'Hawaii',
#  'Hdl (identifier)',
#  'Head of government',
#  'Head of state',
#  'Health in Indonesia',
#  'Healthcare in Indonesia',
#  'Hendrik Merkus de Kock',
#  'High-speed rail in Indonesia',
#  'Highland Papua',
#  'Hikayat Hang Tuah',
#  'Hindu',
#  'Hinduism',
#  'Hinduism in Indonesia',
#  'History of Indonesia',
#  'History of the Jews in Indonesia',
#  'Homelessness in Indonesia',
#  'Homo erectus',
#  'Homo sapiens',
#  'Hong Kong',
#  'Houari Boumediene',
#  'House of Representatives (Indonesia)',
#  'Howland Island',
#  'Hubertus Johannes van Mook',
#  'Hudoq',
#  'Human Development Index',
#  'Human rights in Indonesia',
#  'Humidity',
#  'Hyang',
#  'ISBN (identifier)',
#  'ISNI (identifier)',
#  'ISO 3166',
#  'ISO 3166-2:ID',
#  'ISO 4217',
#  'IUCN Red List',
#  'Ibu Pertiwi',
#  'Ikat',
#  'Imam Bonjol',
#  'Independent city',
#  'Independent film',
#  'Index of Indonesia-related articles',
#  'India',
#  'India and the Non-Aligned Movement',
#  'Indian Ocean',
#  'Indian subcontinent',
#  'Indigenous people of New Guinea',
#  'Indigenous religions',
#  'Indo-Australian Plate',
#  'Indo people',
#  'Indonesia',
#  'Indonesia Raya',
#  'Indonesia Stock Exchange',
#  'Indonesia and the United Nations',
#  'Indonesia at the Olympics',
#  'Indonesia national football team',
#  'Indonesian Aerospace',
#  'Indonesian Agency for Meteorology, Climatology and Geophysics',
#  'Indonesian Air Force',
#  'Indonesian Army',
#  'Indonesian Democratic Party of Struggle',
#  'Indonesian Film Festival',
#  'Indonesian Financial Transaction Reports and Analysis Center',
#  'Indonesian Marine Corps',
#  'Indonesian Maritime Security Agency',
#  'Indonesian National Armed Forces',
#  'Indonesian National Awakening',
#  'Indonesian National Board for Disaster Management',
#  'Indonesian National Police',
#  'Indonesian National Revolution',
#  'Indonesian Navy',
#  'Indonesian State Intelligence Agency',
#  'Indonesian art',
#  'Indonesian cuisine',
#  'Indonesian invasion of East Timor',
#  'Indonesian language',
#  'Indonesian literature',
#  'Indonesian martial arts',
#  'Indonesian mass killings of 1965–66',
#  'Indonesian occupation of East Timor',
#  'Indonesian painting',
#  'Indonesian rupiah',
#  'Indonesians',
#  'Indonesia–Malaysia border',
#  'Indonesia–Malaysia confrontation',
#  'Indonesia–Papua New Guinea border',
#  'Indosat',
#  'Industri Kereta Api',
#  'Infrastructure of Indonesia',
#  'Insurgency in Aceh',
#  'International Futures',
#  'International Organization for Migration',
#  'International Union for Conservation of Nature',
#  'Internet',
#  'Internet service provider',
#  'Investment Coordinating Board (Indonesia)',
#  'Iran',
#  'Iraq',
#  'Islam by country',
#  'Islam in Indonesia',
#  'Islamic missionary activity',
#  'Islamism',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'JSTOR (identifier)',
#  'Jaipongan',
#  'Jakarta',
#  'Jambi',
#  'James Richardson Logan',
#  'Jaminan Kesehatan Nasional',
#  'Jan Gonda',
#  'Japan',
#  'Japanese occupation of the Dutch East Indies',
#  'Japanese occupation of the Dutch East Indies and Portuguese Timor',
#  'Jarvis Island',
#  'Jatiluhur Dam',
#  'Java',
#  'Java Man',
#  'Java War',
#  'Javan rhinoceros',
#  'Javanese historical texts',
#  'Javanese language',
#  'Javanese people',
#  'Jawaharlal Nehru',
#  'Joglo',
#  'Johnston Atoll',
#  'Joko Widodo',
#  'Jordan',
#  'Josip Broz Tito',
#  'Juan Fernández Islands',
#  'Juanda International Airport',
#  'Judaism',
#  'Judicial Commission of Indonesia',
#  'Judiciary of Indonesia',
#  'KAI KF-21 Boramae',
#  'KRI Sultan Iskandar Muda (367)',
#  'KRL Commuterline',
#  'KRL Commuterline Yogyakarta–Solo',
#  'Kacapi suling',
#  'Kaharingan',
#  'Kalimantan',
#  'Kamasan',
#  'Kapuas River',
#  'Karapan sapi',
#  'Kawi language',
#  'Kazakhstan',
#  'Kebaya',
#  'Kejawèn',
#  'Kennedy Space Center',
#  'Keroncong',
#  'Ketoprak',
#  'Ki Hajar Dewantara',
#  'Kilowatt-hour',
#  'Kingdoms of Sunda',
#  'Kingman Reef',
#  'Kiribati',
#  'Komodo National Park',
#  'Komodo dragon',
#  'Kompas',
#  'Kota Tua Jakarta',
#  'Kraton Ngayogyakarta Hadiningrat',
#  'Kris',
#  'Krishna',
#  'Kulintang',
#  'Kuwait',
#  'Kwame Nkrumah',
#  'Kyrgyzstan',
#  'Köppen climate classification',
#  'LGBT rights in Indonesia',
#  'Lake Toba',
#  'Lampung',
#  'Land area',
#  'Languages of Indonesia',
#  'Laos',
#  'Laskar Pelangi',
#  'Law enforcement in Indonesia',
#  'Law of Indonesia',
#  'Lebanon',
#  'Left- and right-hand traffic',
#  'Lenong',
#  'Lesser Sunda Islands',
#  'Liberal democracy period in Indonesia',
#  'Libya',
#  'Liga 1 (Indonesia)',
#  'Lingua franca',
#  'List of ASEAN countries by GDP',
#  'List of ASEAN countries by HDI',
#  'List of ASEAN country subdivisions by GDP',
#  'List of Hikayat',
#  'List of Indonesia-related topics',
#  'List of Indonesian cities by population',
#  'List of Indonesian faunal emblems',
#  'List of Indonesian floral emblems',
#  'List of Indonesian monarchies',
#  'List of Indonesian provinces by GDP',
#  'List of Indonesian provinces by GRP per capita',
#  'List of Indonesian provinces by Human Development Index',
#  'List of Indonesian provinces by highest point',
#  "List of Speakers of the People's Representative Council",
#  'List of World Heritage Sites in Indonesia',
#  'List of banks in Indonesia',
#  'List of beaches in Indonesia',
#  'List of busiest airports by passenger traffic',
#  'List of cities in ASEAN by population',
#  'List of countries and dependencies by area',
#  'List of countries and dependencies by population',
#  'List of countries and dependencies by population density',
#  'List of countries by GDP (PPP)',
#  'List of countries by GDP (PPP) per capita',
#  'List of countries by GDP (nominal)',
#  'List of countries by GDP (nominal) per capita',
#  'List of countries by Human Development Index',
#  'List of current governors in Indonesia',
#  "List of current members of the People's Representative Council",
#  'List of current members of the Regional Representative Council',
#  'List of earthquakes in Indonesia',
#  'List of governors of Yogyakarta',
#  'List of highest-grossing films in Indonesia',
#  'List of islands by population',
#  'List of islands of Indonesia',
#  'List of lakes of Indonesia',
#  'List of largest cities',
#  'List of metropolitan areas in Indonesia',
#  'List of national parks of Indonesia',
#  'List of palaces in Indonesia',
#  'List of political parties in Indonesia',
#  'List of presidents of Indonesia',
#  'List of regencies and cities of Indonesia',
#  'List of rivers of Indonesia',
#  'List of sovereign states and dependent territories in Asia',
#  'List of sovereign states and dependent territories in Oceania',
#  'List of states with limited recognition',
#  'List of vice presidents of Indonesia',
#  'List of volcanoes in Indonesia',
#  'Loetoeng Kasaroeng',
#  'Lombok',
#  'Lombok Strait',
#  'Lonely Planet',
#  'Longhouse',
#  'Lower house',
#  'Ludruk',
#  'Lutheranism',
#  'MBAREA (identifier)',
#  "Ma'ruf Amin",
#  'Macau',
#  'Madhhab',
#  'Madura Island',
#  'Madurese people',
#  'Mahabharata',
#  'Mahakam River',
#  'Mainland China',
#  'Majapahit',
#  'Makassar',
#  'Makassar people',
#  'Malang',
#  'Malay Annals',
#  'Malay Archipelago',
#  'Malay Indonesians',
#  'Malay language',
#  'Malays (ethnic group)',
#  'Malaysia',
#  'Malaysia Agreement',
#  'Maldives',
#  'Mali',
#  'Malnutrition',
#  'Maluku (province)',
#  'Maluku Islands',
#  'Mamberamo River',
#  'Marah Roesli',
#  'Maritime border',
#  'Marshall Islands',
#  'Mass (liturgy)',
#  'Mass media in Indonesia',
#  'Mataram Kingdom',
#  'Mauritania',
#  'May 1998 riots of Indonesia',
#  'Medan',
#  'Media of Indonesia',
#  'Megacity',
#  'Megadiverse countries',
#  'Megalithic art',
#  'Melanesians',
#  'Member states of the Association of Southeast Asian Nations',
#  'Merari Siregar',
#  'Merle Ricklefs',
#  'Merriam-Webster',
#  'Metro TV (Indonesian TV network)',
#  'Mexico',
#  'Middle East',
#  'Middle power',
#  'Midway Atoll',
#  'Military history of Indonesia',
#  'Military of Indonesia',
#  'Minami-Tori-shima',
#  'Minangkabau people',
#  'Ministry of Administrative and Bureaucratic Reform',
#  'Ministry of Agrarian Affairs and Spatial Planning (Indonesia)',
#  'Ministry of Agriculture (Indonesia)',
#  'Ministry of Communication and Information Technology (Indonesia)',
#  'Ministry of Cooperatives and Small & Medium Enterprises (Indonesia)',
#  'Ministry of Defense (Indonesia)',
#  'Ministry of Education, Culture, Research and Technology (Indonesia)',
#  'Ministry of Education and Culture (Indonesia)',
#  'Ministry of Energy and Mineral Resources (Indonesia)',
#  'Ministry of Environment and Forestry (Indonesia)',
#  'Ministry of Finance (Indonesia)',
#  'Ministry of Foreign Affairs (Indonesia)',
#  'Ministry of Health (Indonesia)',
#  'Ministry of Home Affairs (Indonesia)',
#  'Ministry of Industry (Indonesia)',
#  'Ministry of Investment (Indonesia)',
#  'Ministry of Law and Human Rights (Indonesia)',
#  'Ministry of Manpower (Indonesia)',
#  'Ministry of Maritime Affairs and Fisheries (Indonesia)',
#  'Ministry of National Development Planning of Indonesia',
#  "Ministry of Public Works and People's Housing (Indonesia)",
#  'Ministry of Religious Affairs (Indonesia)',
#  'Ministry of Social Affairs (Indonesia)',
#  'Ministry of State Owned Enterprises (Indonesia)',
#  'Ministry of State Secretariat (Indonesia)',
#  'Ministry of Tourism (Indonesia)',
#  'Ministry of Trade (Indonesia)',
#  'Ministry of Transportation (Indonesia)',
#  'Ministry of Villages, Development of Disadvantaged Regions, and Transmigration',
#  'Ministry of Women Empowerment and Child Protection',
#  'Ministry of Youth and Sports (Indonesia)',
#  'Mira Lesmana',
#  'Mixed economy',
#  'Mobile Brigade Corps',
#  'Mohamed Morsi',
#  'Mohammad Hatta',
#  'Mohammad Yamin',
#  'Mongolia',
#  'Monsoon',
#  'Moro National Liberation Front',
#  'Morocco',
#  'Mosque architecture in Indonesia',
#  'Mount Bromo',
#  'Mount Palung National Park',
#  'Mozambique',
#  'Muhammad Syarifuddin',
#  'Multatuli',
#  'Municipal Police (Indonesia)',
#  'Music of Indonesia',
#  'Muslim world',
#  'Myanmar',
#  'NAM News Network',
#  'Nagabonar',
#  'Names of Indonesia',
#  'Nasi Padang',
#  'Nasi goreng',
#  'National Agency of Drug and Food Control (Indonesia)',
#  'National Anti-Narcotics Agency (Indonesia)',
#  'National Archives of Indonesia',
#  'National Civil Service Agency (Indonesia)',
#  'National Counter Terrorism Agency',
#  'National Cyber and Crypto Agency',
#  'National Hero of Indonesia',
#  'National Institute of Aeronautics and Space',
#  'National Intangible Cultural Heritage of Indonesia',
#  'National Library of Indonesia',
#  'National Population and Family Planning Board (Indonesia)',
#  'National Research and Innovation Agency (Indonesia)',
#  'National Resilience Institute',
#  'National Search and Rescue Agency',
#  'National Security Archive',
#  'National Sports Week (Indonesia)',
#  'National costume of Indonesia',
#  'National emblem of Indonesia',
#  'National symbols of Indonesia',
#  'Native Indonesians',
#  'Nauru',
#  'Nelson Mandela',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Guinea',
#  'New Order (Indonesia)',
#  'New Zealand',
#  'Newly industrialised country',
#  'Ngurah Rai International Airport',
#  'Nias people',
#  'Nicolás Maduro',
#  'Niger',
#  'Nigeria',
#  'Niue',
#  'Nobel Prize in Literature',
#  'Non-Aligned Movement',
#  'Non-resident Indian and person of Indian origin',
#  'Norfolk Island',
#  'North Kalimantan',
#  'North Korea',
#  'North Maluku',
#  'North Sulawesi',
#  'North Sumatra',
#  'Northern Cyprus',
#  'Northern Mariana Islands',
#  'Nusa Tenggara',
#  'Nusantara (archipelago)',
#  'Nusantara Capital City Authority',
#  'Nutmeg',
#  'OCLC (identifier)',
#  'OPEC',
#  'Oceania',
#  'Ohio University Press',
#  'Oil palm',
#  'Old town',
#  'Olympic weightlifting',
#  'Oman',
#  'Ombilin Coal Mine',
#  'Oncom',
#  'OpenStreetMap',
#  'Oral tradition',
#  'Orangutan',
#  'Organisation of Islamic Cooperation',
#  'Organisations associated with the Association of Southeast Asian Nations',
#  'Orthodoxy',
#  'Outline of Indonesia',
#  'Overseas Chinese',
#  'Overseas Indonesians',
#  'PMC (identifier)',
#  'PMID (identifier)',
#  'Pacific Islands Forum',
#  'Pacific Ocean',
#  'Pacific Plate',
#  'Padang',
#  'Padang cuisine',
#  'Paddy field',
#  'Pagaruyung Palace',
#  'Pakistan',
#  'Pakualaman',
#  'Palapa',
#  'Palau',
#  'Palembang',
#  'Palm oil',
#  'Palmyra Atoll',
#  'Pancasila (politics)',
#  'Pandava',
#  'Pantun',
#  'Papua (province)',
#  'Papua New Guinea',
#  'Papua conflict',
#  'Papuan languages',
#  'Pasola',
#  'Pattimura',
#  'Pekanbaru',
#  'Pelni',
#  'Pencak Silat',
#  'Pencak silat',
#  'Pendet',
#  'Pendopo',
#  "People's Consultative Assembly",
#  "People's Representative Council",
#  'Peru',
#  'Perusahaan Listrik Negara',
#  'Pesantren',
#  'Petualangan Sherina',
#  'Philippines',
#  'Pinisi',
#  'Piper cubeba',
#  'Pitcairn Islands',
#  'Politics of Indonesia',
#  'Port of Tanjung Priok',
#  'Portuguese colonialism in Indonesia',
#  'Portuguese colonialism in Indonesian history',
#  'Portuguese colonialism in the East Indies',
#  'Post-Suharto era in Indonesia',
#  'Prambanan',
#  'Pramoedya Ananta Toer',
#  'President of Indonesia',
#  'Presidential system',
#  'Prestige (sociolinguistics)',
#  'Primate city',
#  'Prince Diponegoro',
#  'Princeton University Press',
#  'Proclamation of Indonesian Independence',
#  'Prosperous Justice Party',
#  'Prostitution in Indonesia',
#  'Protected areas of Indonesia',
#  'Protestantism in Indonesia',
#  'Proto-Austronesian language',
#  'Provinces of Indonesia',
#  'Puan Maharani',
#  'Public Prosecution Service (Indonesia)',
#  'Public domain',
#  'Public holidays in Indonesia',
#  'Puncak Jaya',
#  'Purchasing power parity',
#  'Purwakarta Regency',
#  'QS World University Rankings',
#  'Qanbūs',
#  'Qasida',
#  'Qatar',
#  'Rafflesia arnoldii',
#  'Rail transport in Indonesia',
#  'Raja Ampat Islands',
#  'Ramayana',
#  'Randai',
#  'Rangkiang',
#  'Rapid transit',
#  'Realm of New Zealand',
#  'Refugees in Indonesia',
#  'Regency (Indonesia)',
#  'Regional Comprehensive Economic Partnership',
#  'Regional Representative Council',
#  'Regional power',
#  'Regions of Indonesia',
#  'Religion in Indonesia',
#  'Rendang',
#  'Republic',
#  'Republic of Artsakh',
#  'Republika (Indonesian newspaper)',
#  'Riau',
#  'Riau Islands',
#  'Rice barn',
#  'Rickshaw',
#  'Ring of Fire',
#  'Riri Riza',
#  'Roman Catholicism in Indonesia',
#  'Routledge',
#  'Rumah Gadang',
#  'Rumah Melayu',
#  'Rumah adat',
#  'Russia',
#  'S2CID (identifier)',
#  'SUDOC (identifier)',
#  'Sailendra',
#  'Salakanagara',
#  'Samarinda',
#  'Samoa',
#  'Sandiwara',
#  'Sanskrit',
#  'Sape Strait',
#  'Sasak people',
#  'Sasando',
#  "Satan's Slave (1980 film)",
#  'Satay',
#  'Saudi Arabia',
#  'Science and technology in Indonesia',
#  'Sea level rise',
#  'Sebatik Island',
#  'Secretary General of the Association of Southeast Asian Nations',
#  'Semarang',
#  'Semeru',
#  'http://www.ifs.du.edu/ifs/frm_CountryProfile.aspx?Country=ID',
#  'http://globalshakespeares.mit.edu/glossary/randai/',
#  'http://spacejournal.ohio.edu/issue8/his_marwah3.html',
#  'http://www.press.uchicago.edu/Misc/Chicago/468283.html',
#  'http://digital.law.washington.edu/dspace-law/bitstream/handle/1773.1/1091/21PRPLJ013.pdf',
#  'http://www.cleanitproject.eu/wp-content/uploads/2012/07/2010-Radical-websites-Indonesia.pdf',
#  'http://www.persee.fr/doc/arch_0044-8613_1976_num_12_1_1296',
#  'http://lcweb2.loc.gov/cgi-bin/query/r?frd/cstdy:@field(DOCID+id0029)',
#  'http://pubmed.ncbi.nlm.nih.gov/29961639',
#  'http://pubmed.ncbi.nlm.nih.gov/30375988',
#  'http://pubmed.ncbi.nlm.nih.gov/6410399',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC384173',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC6099123',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC6207062',
#  'http://indonesia.gr/indonesian-culture-arts-and-traditions/',
#  'http://transjakarta.co.id/produk-dan-layanan/infrastruktur/koridor/',
#  'http://waspada.co.id/index.php?option=com_content&view=article&id=182106:fifty-years-needed-to-bring-population-growth-to-zero&catid=30:english-news&Itemid=101',
#  'http://demografi.bps.go.id/phpFileTree/bahan/kumpulan_tugas_mobilitas_pak_chotib/Kelompok_1/Referensi/Jill_Forshee_Culture_and_Customs_of_Indonesia_Culture_and_Customs_of_Asia__2006.pdf',
#  'http://www.bps.go.id/',
#  'http://www.bps.go.id/website/pdf_publikasi/watermark%20_Kewarganegaraan,%20Suku%20Bangsa,%20Agama%20dan%20Bahasa_281211.pdf',
#  'http://www.setneg.go.id/',
#  'http://www.expat.or.id/info/artshandicrafts-indonesia.html',
#  'http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007552504805171',
#  'http://www.searo.who.int/entity/health_situation_trends/cp_ino.pdf?ua=1',
#  'http://skemman.is/stream/get/1946/3303/10384/1/Sylviane_Lebon_fixed.pdf',
#  'http://www.buddhanet.net/e-learning/buddhistworld/indo-txt.htm',
#  'http://hdl.handle.net/115%2F13163',
#  'http://hdl.handle.net/1813%2F53928',
#  'http://hdl.handle.net/20.500.11755%2Fc467167b-2084-413c-a3c7-f390f9b3a092',
#  'http://www.islamonline.net/English/Science/2003/05/article13.shtml',
#  'http://mekongdmp.net/data/Resourcespapers/filepdf/PromisedLand.pdf',
#  'http://reformiert-online.net/weltweit/64_eng.php',
#  'http://www.nidi.knaw.nl/Content/NIDI/output/reports/nidi-report-64.pdf',
#  'http://www.cartercenter.org/documents/2161.pdf',
#  'http://www.crisisgroup.org/library/documents/asia/indonesia/b53_papua_answers_to_frequently_asked_questions.pdf',
#  'http://devinit.org/wp-content/uploads/2013/09/Investments-to-End-Poverty-Chapter-10-Indonesia.pdf',
#  'http://doi.org/10.1002%2F9781118663202.wberen460',
#  'http://doi.org/10.1016%2F0016-3287(82)90071-4',
#  'http://doi.org/10.1016%2FS0140-6736(18)30595-6',
#  'http://doi.org/10.1016%2Fj.landusepol.2016.05.034',
#  'http://doi.org/10.1038%2Fsdata.2018.214',
#  'http://doi.org/10.1073%2Fpnas.80.16.4988',
#  'http://doi.org/10.1080%2F10357823.2018.1473335',
#  'http://doi.org/10.1080%2F1462394042000326879',
#  'http://doi.org/10.1080%2F1463136042000259789',
#  'http://doi.org/10.1080%2F15570274.2018.1433588',
#  'http://doi.org/10.1088%2F1748-9326%2Faaf6db',
#  'http://doi.org/10.1093%2Fcje%2F22.6.723',
#  'http://doi.org/10.1093%2Ficon%2Fmoi055',
#  'http://doi.org/10.1126%2Fscience.7992059',
#  'http://doi.org/10.1146%2Fannurev.an.17.100188.000355',
#  'http://doi.org/10.1162%2F105420498760308706',
#  'http://doi.org/10.1353%2Fecs.1998.0021',
#  'http://doi.org/10.1525%2Fas.2002.42.4.550',
#  'http://doi.org/10.1525%2Fas.2005.45.4.645',
#  'http://doi.org/10.17528%2Fcifor%2F005695',
#  'http://doi.org/10.2305%2FIUCN.UK.2008.RLTS.T19495A8925965.en',
#  'http://doi.org/10.2305%2FIUCN.UK.2016-3.RLTS.T22710912A94267053.en',
#  'http://doi.org/10.2307%2F2613527',
#  'http://doi.org/10.2307%2F3016666',
#  'http://doi.org/10.2307%2F3023219',
#  'http://doi.org/10.2307%2F3351057',
#  'http://doi.org/10.2307%2F595186',
#  'http://doi.org/10.3390%2Fsu14148621',
#  'http://doi.org/10.3406%2Farch.1976.1296',
#  'http://www.eastasiaforum.org/2017/12/02/why-does-indonesia-seem-to-prefer-foreign-aid-from-china/',
#  'http://www.embassyofindonesia.org/basic-facts/',
#  'http://www.gamelan.org/balungan/back_issues/balungan(9-10)/2-Ruslaiana_Dancedrama.pdf',
#  'http://www.globalsecurity.org/military/world/war/indo-inde.htm',
#  'http://www.ilo.org/wcmsp5/groups/public/---ed_protect/---protrav/---ilo_aids/documents/legaldocument/wcms_174556.pdf',
#  'http://www.imf.org/external/pubs/ft/survey/so/2009/car072809b.htm',
#  'http://www.imf.org/external/pubs/ft/weo/2017/02/weodata/weorept.aspx?pr.x=42&pr.y=11&sy=2007&ey=2017&scsm=1&ssd=1&sort=country&ds=.&br=1&c=536&s=NGDP_RPCH&grp=0&a=',
#  'http://www.insideindonesia.org/review-indonesian-post-colonial-theatre',
#  'http://www.jstor.org/stable/10.1525/as.2005.45.4.645',
#  'http://www.jstor.org/stable/2613527',
#  'http://www.jstor.org/stable/3016666',
#  'http://www.jstor.org/stable/3023219',
#  'http://www.jstor.org/stable/3351057',
#  'http://www.jstor.org/stable/595186',
#  'http://awsassets.panda.org/downloads/inodesian_climate_change_impacts_report_14nov07.pdf',
#  'http://papuaweb.org/dlib/s123/upton/_phd.pdf',
#  'http://www.pewforum.org/2011/01/27/future-of-the-global-muslim-population-sunni-and-shia/',
#  'http://www.pewforum.org/2018/06/13/how-religious-commitment-varies-by-country-among-people-of-all-ages/',
#  'http://www.sil.org/asia/ldc/parallel_papers/unesco_jakarta.pdf',
#  'http://www.survivalinternational.org/news/2191',
#  'http://geohack.toolforge.org/geohack.php?pagename=Indonesia&params=5_S_120_E_type:country_region:ID',
#  'http://geohack.toolforge.org/geohack.php?pagename=Indonesia&params=6_10_S_106_49_E_type:city_region:ID',
#  'https://www.republika.co.id/berita/re9xvl436/tok-dpr-sahkan-tiga-ruu-dob-papua-jadi-undangundang',
#  'https://peraturan.bpk.go.id/Home/Details/162614/perda-no-2-tahun-2021',
#  'https://www.bps.go.id/indicator/16/327/3/jumlah-kedatangan-wisatawan-mancanegara-ke-indonesia-menurut-negara-tempat-tinggal.html',
#  'https://www.bps.go.id/linkTableDinamis/view/id/820',
#  'https://www.bps.go.id/website/materi_ind/materiBrsInd-20210121151046.pdf',
#  'https://gatrik.esdm.go.id/assets/uploads/download_index/files/c4053-statistik-2019-highres.pdf',
#  'https://www.indonesia.go.id/narasi/indonesia-dalam-angka/ekonomi/menempatkan-orang-papua-asli-sebagai-subjek-utama-pembangunan',
#  'https://gln.kemdikbud.go.id/glnsite/diaspora-melanesia-di-nusantara/',
#  'https://kebudayaan.kemdikbud.go.id/muspres/sejarah-wilayah-indonesia/',
#  'https://data.kemenag.go.id/agamadashboard/statistik/umat',
#  'https://kemlu.go.id/portal/id/page/29/kedutaan_konsulat',
#  'https://www.komisiyudisial.go.id/frontend/static_content/authority_and_duties/about_ky',
#  'https://jakartaglobe.id/lifestyle/introduction-literature-indonesia-2015-frankfurt-book-fairs-guest-honor/',
#  'https://fois.or.id/tapping-the-indonesian-diaspora-potential-97baef4e98ba?gi=fa637167c9c7',
#  'https://tirto.id/musik-di-tengah-konflik-indonesia-malaysia-cu8t',
#  'https://www.bh.org.il/jewish-community-indonesia/',
#  'https://d-nb.info/gnd/4026761-1',
#  'https://reliefweb.int/report/indonesia/situation-human-rights-east-timor',
#  'https://www.overtureglobal.io/story/at-last-light-rail-comes-to-jakarta',
#  'https://id.ndl.go.jp/auth/ndlna/00871922',
#  'https://www.researchgate.net/publication/320622312',
#  'https://www.researchgate.net/publication/326286879',
#  'https://seadelt.net/Asset/Source/Document_ID-184_No-01.pdf',
#  'https://pure.knaw.nl/portal/files/488440/16390.pdf',
#  'https://researcharchive.vuw.ac.nz/xmlui/bitstream/handle/10063/4977/thesis.pdf?sequence=1',
#  'https://archive.org/details/contemporaryasia0000unse/page/96',
#  'https://archive.org/details/historyofmoderni00adri',
#  'https://archive.org/details/historyofmoderni00adri/page/n27',
#  'https://archive.org/details/indonesia00jean',
#  'https://archive.org/details/indonesia00jean/page/209',
#  'https://archive.org/details/indonesia00jean/page/325',
#  'https://archive.org/details/indonesiandestin00theo',
#  'https://archive.org/details/indonesiandestin00theo/page/21',
#  'https://archive.org/details/indonesiandestin00theo/page/23',
#  'https://archive.org/details/nationinwaitingi00schw',
#  'https://archive.org/details/shorthistoryindo00brow',
#  'https://archive.org/details/shorthistoryindo00brow/page/n31',
#  'https://web.archive.org/web/20060822194320/http://news.bbc.co.uk/2/hi/asia-pacific/3809079.stm',
#  'https://web.archive.org/web/20060914023845/http://cui.unige.ch/~luthi/download/indo.html',
#  'https://web.archive.org/web/20060918233640/http://www.crisisgroup.org/library/documents/asia/indonesia/b53_papua_answers_to_frequently_asked_questions.pdf',
#  'https://web.archive.org/web/20210120234321/https://www.equaltimes.org/slow-progress-in-the-fight-against',
#  'https://web.archive.org/web/20210122154418/https://www.bps.go.id/website/materi_ind/materiBrsInd-20210121151046.pdf',
#  'https://web.archive.org/web/20210125054232/https://www.fimela.com/news-entertainment/read/2982723/editor-says-ketika-musik-indonesia-berjaya-di-negeri-tetangga',
#  'https://web.archive.org/web/20210513132842/https://properti.kompas.com/read/2011/10/26/08061555/presiden.kunjungi.pt.dirgantara.indonesia.',
#  'https://web.archive.org/web/20210928070135/https://www.ksi-indonesia.org/assets/uploads/original/2021/02/ksi-1613637314.pdf',
#  'https://web.archive.org/web/20210928071917/https://gatrik.esdm.go.id/assets/uploads/download_index/files/c4053-statistik-2019-highres.pdf',
#  'https://web.archive.org/web/20220622092437/https://openknowledge.worldbank.org/handle/10986/37584',
#  'https://australiaindonesiacentre.org/app/uploads/2018/09/Guide-to-the-2019-Presidential-Elections-Kevin-Evans.pdf',
#  'https://climatecentral.org/news/report-flooded-future-global-vulnerability-to-sea-level-rise-worse-than-previously-understood',
#  'https://curlie.org/Regional/Asia/Indonesia',
#  'https://www.embassyofindonesia.org/index.php/basic-facts/',
#  'https://www.equaltimes.org/slow-progress-in-the-fight-against',
#  'https://g20.org/',
#  'https://www.globalinnovationindex.org/gii-2021-report',
#  'https://www.globalslaveryindex.org/2018/findings/executive-summary/',
#  'https://www.imf.org/en/Publications/WEO/weo-database/2022/April/weo-report?c=536,&s=NGDP_RPCH,NGDPD,PPPGDP,NGDPDPC,PPPPC,PPPSH,NID_NGDP,NGSD_NGDP,LUR,LP,BCA,BCA_NGDPD,&sy=2020&ey=2027&ssm=0&scsm=1&scc=0&ssd=1&ssc=0&sic=0&sort=country&ds=.&br=1',
#  'https://www.impactlab.org/map/#usmeas=absolute&usyear=1981-2010&gmeas=change-from-hist&gyear=2080-2099&tab=global&gvar=tasmax-over-95F&gprob=0.5&grcp=rcp85',
#  'https://www.insideindonesia.org/the-village-head-as-patron-2',
#  'https://isni.org/isni/0000000403921382',
#  'https://www.iucn.org/content/extinction-crisis-escalates-red-list-shows-apes-corals-vultures-dolphins-all-danger',
#  'https://www.iucnredlist.org/species/19495/8925965',
#  'https://www.iucnredlist.org/species/22710912/94267053',
#  'https://www.ksi-indonesia.org/assets/uploads/original/2021/02/ksi-1613637314.pdf',
#  'https://musicbrainz.org/area/d3a68bd0-7419-3f99-a5bd-204d6e057089',
#  'https://www.openstreetmap.org/relation/304751',
#  'https://ourworldindata.org/grapher/child-mortality-igme',
#  'https://ourworldindata.org/grapher/life-expectancy',
#  'https://ourworldindata.org/grapher/share-of-population-urban',
#  'https://www.refworld.org/docid/55a619124.html',
#  'https://semanticscholar.org/paper/aa9b073fd95ecbc825767210f1afb1a724171b8b',
#  'https://api.semanticscholar.org/CorpusID:143311407',
#  'https://api.semanticscholar.org/CorpusID:145130614',
#  'https://api.semanticscholar.org/CorpusID:145646994',
#  'https://api.semanticscholar.org/CorpusID:150302264',
#  'https://api.semanticscholar.org/CorpusID:161921454',
#  'https://api.semanticscholar.org/CorpusID:57565023',
#  'https://socialhistory.org/sites/default/files/docs/ecgrowtheng.pdf',
#  'https://www.sydneycatholic.org/events/pilgrimageofgrace/about.shtml',
#  'https://esa.un.org/unpd/wpp/Publications/Files/WPP2017_DataBooklet.pdf',
#  'https://hdr.undp.org/system/files/documents/global-report-document/hdr2021-22pdf_1.pdf',
#  'https://ich.unesco.org/en/RL/indonesian-batik-00170',
#  'https://ich.unesco.org/en/state/indonesia-ID?info=elements-on-the-lists',
#  'https://whc.unesco.org/en/list/592',
#  'https://whc.unesco.org/en/statesparties/id',
#  'https://viaf.org/viaf/125405737',
#  'https://www.wikidata.org/wiki/Q252#identifiers',
#  'https://data.worldbank.org/indicator/AG.LND.FRST.ZS?locations=ID',
#  'https://data.worldbank.org/indicator/SI.POV.GINI?locations=ID',
#  'https://data.worldbank.org/indicator/ms.mil.xpnd.gd.zs?end=2018&start=2007&view=chart',
#  'https://openknowledge.worldbank.org/handle/10986/37584',
#  'https://www.worldcat.org/identities/lccn-n80083633/',
#  'https://www.worldcat.org/oclc/4458152',
#  'https://www.nhb.gov.sg/spm/-/media/spm/documents/indonesia-land-of-dance-and-dragon.pdf?la=en',
#  'https://archive.today/20220422045550/https://www.ft.com/content/d2c24350-7910-11e7-a3e8-60495fe6ca71',
#  'https://www.aa.com.tr/en/asia-pacific/indonesia-s-economy-grew-last-year-despite-shortfalls/1697593',
#  'https://islamansiklopedisi.org.tr/endonezya',
#  'https://www.lancaster.ac.uk/jais/volume/docs/vol14/v14_03_tan_047-062.pdf',
#  'https://www.bbc.co.uk/news/world-asia-pacific-14921238',
#  'https://www.independent.co.uk/asia/southeast-asia/indonesia-papua-police-chief-rebels-b1851320.html',
#  'https://www.prospectmagazine.co.uk/magazine/pramoedya',
#  'https://oec.world/en/profile/country/idn']

# %%
page.summary
# Out:
# 'Indonesia, officially the Republic of Indonesia, is a country in Southeast Asia and Oceania between the Indian and Pacific oceans. It consists of over 17,000 islands, including Sumatra, Java, Sulawesi, and parts of Borneo and New Guinea. Indonesia is the world\'s largest archipelagic state and the 14th-largest country by area, at 1,904,569 square kilometres (735,358 square miles). With over 277 million people, Indonesia is the world\'s fourth-most populous country and the most populous Muslim-majority country. Java, the world\'s most populous island, is home to more than half of the country\'s population.\nIndonesia is a presidential republic with an elected legislature. It has 37 provinces, of which eight have special status. The country\'s capital, Jakarta, is the world\'s second-most populous urban area. Indonesia shares land borders with Papua New Guinea, East Timor, and the eastern part of Malaysia, as well as maritime borders with Singapore, Vietnam, Thailand, the Philippines, Australia, Palau, and India (Andaman and Nicobar Islands). Despite its large population and densely populated regions, Indonesia has vast areas of wilderness that support one of the world\'s highest levels of biodiversity.\nThe Indonesian archipelago has been a valuable region for trade since at least the 7th century when Srivijaya and later Majapahit traded with entities from mainland China and the Indian subcontinent. Local rulers gradually absorbed foreign influences from the early centuries, and Hindu and Buddhist kingdoms flourished. Sunni traders and Sufi scholars brought Islam, while Christianity was spread by European missionaries. Although the Portuguese, the French and British also ruled at some point, the Dutch were the foremost colonial power for much of their 350-year presence in the archipelago. The concept of "Indonesia" as a nation-state emerged in the early 20th century, culminating later in the proclamation of Indonesian Independence in 1945. However, it was not until 1949 that the Dutch recognised Indonesia\'s sovereignty following an armed and diplomatic conflict between the two.\nIndonesia consists of thousands of distinct native ethnic and hundreds of linguistic groups, with Javanese being the largest. A shared identity has developed with the motto "Bhinneka Tunggal Ika" ("Unity in Diversity" literally, "many, yet one"), defined by a national language, cultural diversity, religious pluralism within a Muslim-majority population, and a history of colonialism and rebellion against it. The economy of Indonesia is the world\'s 17th-largest by nominal GDP and the 7th-largest by PPP. It is a regional power and is considered a middle power in global affairs. The country is a member of several multilateral organisations, including the United Nations, World Trade Organization, G20, and a founding member of the Non-Aligned Movement, Association of Southeast Asian Nations, East Asia Summit, D-8 and the Organisation of Islamic Cooperation.'

# %%
# Available languages https://meta.wikimedia.org/wiki/List_of_Wikipedias
wikipedia.set_lang('en')

# %%
wikipedia.page("Indonesia").summary
# Out:
# 'Indonesia, officially the Republic of Indonesia, is a country in Southeast Asia and Oceania between the Indian and Pacific oceans. It consists of over 17,000 islands, including Sumatra, Java, Sulawesi, and parts of Borneo and New Guinea. Indonesia is the world\'s largest archipelagic state and the 14th-largest country by area, at 1,904,569 square kilometres (735,358 square miles). With over 277 million people, Indonesia is the world\'s fourth-most populous country and the most populous Muslim-majority country. Java, the world\'s most populous island, is home to more than half of the country\'s population.\nIndonesia is a presidential republic with an elected legislature. It has 37 provinces, of which eight have special status. The country\'s capital, Jakarta, is the world\'s second-most populous urban area. Indonesia shares land borders with Papua New Guinea, East Timor, and the eastern part of Malaysia, as well as maritime borders with Singapore, Vietnam, Thailand, the Philippines, Australia, Palau, and India (Andaman and Nicobar Islands). Despite its large population and densely populated regions, Indonesia has vast areas of wilderness that support one of the world\'s highest levels of biodiversity.\nThe Indonesian archipelago has been a valuable region for trade since at least the 7th century when Srivijaya and later Majapahit traded with entities from mainland China and the Indian subcontinent. Local rulers gradually absorbed foreign influences from the early centuries, and Hindu and Buddhist kingdoms flourished. Sunni traders and Sufi scholars brought Islam, while Christianity was spread by European missionaries. Although the Portuguese, the French and British also ruled at some point, the Dutch were the foremost colonial power for much of their 350-year presence in the archipelago. The concept of "Indonesia" as a nation-state emerged in the early 20th century, culminating later in the proclamation of Indonesian Independence in 1945. However, it was not until 1949 that the Dutch recognised Indonesia\'s sovereignty following an armed and diplomatic conflict between the two.\nIndonesia consists of thousands of distinct native ethnic and hundreds of linguistic groups, with Javanese being the largest. A shared identity has developed with the motto "Bhinneka Tunggal Ika" ("Unity in Diversity" literally, "many, yet one"), defined by a national language, cultural diversity, religious pluralism within a Muslim-majority population, and a history of colonialism and rebellion against it. The economy of Indonesia is the world\'s 17th-largest by nominal GDP and the 7th-largest by PPP. It is a regional power and is considered a middle power in global affairs. The country is a member of several multilateral organisations, including the United Nations, World Trade Organization, G20, and a founding member of the Non-Aligned Movement, Association of Southeast Asian Nations, East Asia Summit, D-8 and the Organisation of Islamic Cooperation.'
